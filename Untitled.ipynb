# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
iris = pd.read_csv("Resources/dataset.csv")
print(iris.head())
print(iris.info())
print(iris.info())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.plot(kind="scatter", x="sepal_length",   y="sepal_width")
plt.show()

# %%
data =iris.drop(iris.iloc[:,:0])

# %%
from pandas.plotting import andrews_curves
andrews_curves(iris,"species")
plt.show()

# %%
sns.pairplot(data,hue="species")

# %%
sns.boxplot(x="species",y="sepal_length",data=iris)
plt.show()

# %%
sns.boxplot(x="species",y="sepal_width",data=iris)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression  # for Logistic Regression algorithm
from sklearn.model_selection import train_test_split #to split the dataset for training and testing
from sklearn.neighbors import KNeighborsClassifier  # for K nearest neighbours
from sklearn import svm  #for Support Vector Machine (SVM) Algorithm
from sklearn import metrics #for checking the model accuracy

# %%
plt.figure(figsize=(9,4)) 
sns.heatmap(iris.corr(),annot=True,cmap='cubehelix_r') 
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='sepal_length',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='sepal_width',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='petal_length',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='petal_width',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
from collections import Counter
Counter(iris)
# Out:
# Counter({'sepal_length': 1,
#          'sepal_width': 1,
#          'petal_length': 1,
#          'petal_width': 1,
#          'species': 1})

# %% [markdown]
# ## Training And Testing Dataset

# %%
train, test = train_test_split(data, test_size = 0.3)
print(train.shape)
print(test.shape)
# Out:
# (105, 5)
# (45, 5)

# %%
train_X = train[['sepal_length','sepal_width','petal_length','petal_width']]
train_y=train.species

test_X = test[['sepal_length','sepal_width','petal_length','petal_width']]
test_y=test.species

# %%
model = svm.SVC()
model.fit(train_X,train_y)
prediction = model.predict(test_X)
print('The accuracy of the SVM is:',metrics.accuracy_score(prediction,test_y))
# Out:
# The accuracy of the SVM is: 0.9777777777777777

# %%
model = LogisticRegression()
model.fit(train_X,train_y)
prediction=model.predict(test_X)
print('The accuracy of the Logistic Regression is',metrics.accuracy_score(prediction,test_y))
# Out:
# The accuracy of the Logistic Regression is 0.9777777777777777

# %%
model=KNeighborsClassifier(n_neighbors=15)
model.fit(train_X,train_y)
prediction=model.predict(test_X)
print('The accuracy of the KNN is',metrics.accuracy_score(prediction,test_y))
# Out:
# The accuracy of the KNN is 0.9777777777777777

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

model.compile(optimizer='sgd', loss='mean_squared_error')
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)
model.fit(xs, ys, epochs=50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 178ms/step - loss: 51.3571
# Epoch 2/50
# 1/1 [==============================] - 0s 2ms/step - loss: 40.4059
# Epoch 3/50
# 1/1 [==============================] - 0s 2ms/step - loss: 31.7900
# Epoch 4/50
# 1/1 [==============================] - 0s 2ms/step - loss: 25.0114
# Epoch 5/50
# 1/1 [==============================] - 0s 4ms/step - loss: 19.6783
# Epoch 6/50
# 1/1 [==============================] - 0s 3ms/step - loss: 15.4825
# Epoch 7/50
# 1/1 [==============================] - 0s 2ms/step - loss: 12.1815
# Epoch 8/50
# 1/1 [==============================] - 0s 2ms/step - loss: 9.5843
# Epoch 9/50
# 1/1 [==============================] - 0s 2ms/step - loss: 7.5410
# Epoch 10/50
# 1/1 [==============================] - 0s 2ms/step - loss: 5.9334
# Epoch 11/50
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6686
# Epoch 12/50
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6736
# Epoch 13/50
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8907
# Epoch 14/50
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2747
# Epoch 15/50
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7901
# Epoch 16/50
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4088
# Epoch 17/50
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1088
# Epoch 18/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8728
# Epoch 19/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6871
# Epoch 20/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5410
# Epoch 21/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4261
# Epoch 22/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3356
# Epoch 23/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2644
# Epoch 24/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2084
# Epoch 25/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1644
# Epoch 26/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1297
# Epoch 27/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1024
# Epoch 28/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0809
# Epoch 29/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0640
# Epoch 30/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0507
# Epoch 31/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0402
# Epoch 32/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0320
# Epoch 33/50
# 1/1 [==============================] - 0s 1000us/step - loss: 0.0255
# Epoch 34/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0204
# Epoch 35/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0163
# Epoch 36/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 37/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0106
# Epoch 38/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 39/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 40/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0059
# Epoch 41/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 42/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 43/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 44/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 45/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 46/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 47/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 48/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 49/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 50/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016

# %%
print(model.predict([10.0]))
# Out:
# [[31.02507]]

# %% [markdown]
# ## Save the model in pickle

# %%
from sklearn.linear_model import LogisticRegression
import pickle
model = LogisticRegression()
model.fit(train_X, train_y)

# save the model to disk
filename = 'model.sav'
pickle.dump(model, open(filename, 'wb'))


#load the model
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(test_X, test_y)
print(result)
# Out:
# 0.9777777777777777

# %%
with open('model.pkl', 'wb') as files:
    pickle.dump(model, files)
result = loaded_model.score(test_X, test_y)
print(result)
# Out:
# 0.9777777777777777
